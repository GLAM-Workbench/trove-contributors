# %% [markdown]
# # Get the number of records from each contributor by zone and format
#
# In [another notebook](get_contributors.ipynb) I saved a flat list of Trove's metadata contributors. This notebook uses that list to find out the number of records contributed by each organisation, aggregated by zone and format, and does a little exploration of the data.
#
# The code in this notebook is used to create weekly harvests of data about Trove contributors which are saved [in this repository](https://github.com/wragge/trove-contributor-totals).
#
# The method used is straightforward:
#
# - loop through the list of contributors
# - using the query pattern `nuc:"[contributor NUC]"` search all zones for items from that contributor
# - add the `facet=format` parameter to the search to get facets by item format
# - process the results by zone and facet to get totals from each contributor

# %% [markdown]
# ## Set things up

# %%
import datetime
import os
import time

import pandas as pd
import requests
from requests.adapters import HTTPAdapter
from requests.packages.urllib3.util.retry import Retry
from tqdm.auto import tqdm

# Create a session that will automatically retry on server errors
s = requests.Session()
retries = Retry(total=5, backoff_factor=1, status_forcelist=[502, 503, 504])
s.mount("http://", HTTPAdapter(max_retries=retries))
s.mount("https://", HTTPAdapter(max_retries=retries))

# %%
# %%capture
# Load variables from the .env file if it exists
# Use %%capture to suppress messages
# %load_ext dotenv
# %dotenv

# %%
# Insert your Trove API key
API_KEY = "YOUR API KEY"

if os.getenv("TROVE_API_KEY"):
    API_KEY = os.getenv("TROVE_API_KEY")

# %% [markdown]
# ## Define some functions

# %%
def get_children(facet_type, term):
    """
    Get child terms of the current facet term.
    """
    facets = []
    for child_term in term["term"]:
        facets += get_term(facet_type, child_term)
    return facets


def get_term(facet_type, term):
    """
    Gets details of an individual facet term as well as any child terms.
    Return a list of facet terms
    """
    facets = []
    facets.append({facet_type: term["search"], "total": int(term["count"])})
    if "term" in term:
        facets += get_children(facet_type, term)
    return facets


def get_facet_values(zone, facet_type):
    """
    Get all of the terms for a particular from the given zone.
    """
    facet_values = []
    # If there are no facet values you might either get and empty string or no facets at all
    if "facets" in zone and zone["facets"]:
        # If there are multiple facets then facets will be a list, otherwise a dict
        if isinstance(zone["facets"]["facet"], list):
            facets = zone["facets"]["facet"]
        else:
            facets = [zone["facets"]["facet"]]
        for facet in facets:
            if facet["name"] == facet_type:
                for term in facet["term"]:
                    facet_values += get_term(facet_type, term)
    return facet_values


def get_contrib_totals():
    params = {
        "zone": "article,book,collection,map,music,people,picture",
        "facet": "format",
        "encoding": "json",
        "n": 0,
        "key": API_KEY,
    }
    contributors = pd.read_csv(
        "https://raw.githubusercontent.com/wragge/trove-contributor-totals/main/data/trove-contributors.csv"
    ).to_dict("records")
    totals = []
    formats = []
    for contrib in tqdm(contributors):
        if nuc := contrib["nuc"]:
            params["q"] = f'nuc:"{nuc}"'
            response = s.get("https://api.trove.nla.gov.au/v2/result", params=params)
            data = response.json()
            for zone in data["response"]["zone"]:
                totals.append(
                    {
                        "nuc": nuc,
                        "name": contrib["name"],
                        "zone": zone["name"],
                        "total": zone["records"]["total"],
                    }
                )
                facets = get_facet_values(zone, "format")
                for facet in facets:
                    facet.update(
                        {"nuc": nuc, "name": contrib["name"], "zone": zone["name"]}
                    )
                    formats.append(facet)
            time.sleep(0.2)
    return totals, formats

# %% [markdown]
# Harvest the data.

# %%
totals, formats = get_contrib_totals()

# %% [markdown]
# Convert the harvested data to dataframes.

# %%
df_totals = pd.DataFrame(totals)
df_formats = pd.DataFrame(formats)

# %%
df_totals.head()
# Out:
#      nuc                                                                 name  \
# 0  VPWLH  4th/19th Prince of Wales'  Light Horse Regiment Unit. History Room.
# 1  VPWLH  4th/19th Prince of Wales'  Light Horse Regiment Unit. History Room.
# 2  VPWLH  4th/19th Prince of Wales'  Light Horse Regiment Unit. History Room.
# 3  VPWLH  4th/19th Prince of Wales'  Light Horse Regiment Unit. History Room.
# 4  VPWLH  4th/19th Prince of Wales'  Light Horse Regiment Unit. History Room.
#
#          zone  total
# 0      people      0
# 1         map      0
# 2       music      0
# 3     article      3
# 4  collection     22

# %%
df_formats.head()
# Out:
#                                                                   name    nuc  \
# 0  4th/19th Prince of Wales'  Light Horse Regiment Unit. History Room.  VPWLH
# 1  4th/19th Prince of Wales'  Light Horse Regiment Unit. History Room.  VPWLH
# 2  4th/19th Prince of Wales'  Light Horse Regiment Unit. History Room.  VPWLH
# 3  4th/19th Prince of Wales'  Light Horse Regiment Unit. History Room.  VPWLH
# 4  4th/19th Prince of Wales'  Light Horse Regiment Unit. History Room.  VPWLH
#
#       zone                               format  total
# 0  article                              Article      2
# 1  article                Article/Other article      1
# 2  article                       Article/Report      1
# 3  article                           Periodical      1
# 4  article  Periodical/Journal, magazine, other      1

# %% [markdown]
# Save the harvested data as CSV files.

# %%
df_totals[["nuc", "name", "zone", "total"]].to_csv(
    f"trove-contributors-zones-{datetime.datetime.now().strftime('%Y%m%d')}.csv",
    index=False,
)

df_formats[["nuc", "name", "zone", "format", "total"]].to_csv(
    f"trove-contributors-formats-{datetime.datetime.now().strftime('%Y%m%d')}.csv",
    index=False,
)

# %% [markdown]
# ## Top contributors by zone
#
# Let's do a little exploration of the data. First we'll set some Pandas defaults, and make sure the data is loaded.

# %%
pd.set_option("display.max_colwidth", None)
pd.set_option("styler.format.thousands", ",")

# If you haven't created a fresh harvest above, you can load the most recent weekly harvest
try:
    # Make sure totals are ints
    df_totals["total"] = df_totals["total"].astype("Int64")
    df_formats["total"] = df_formats["total"].astype("Int64")
except NameError:
    df_totals = pd.read_csv(
        "https://raw.githubusercontent.com/wragge/trove-contributor-totals/main/data/trove-contributors-zones.csv"
    )
    df_formats = pd.read_csv(
        "https://raw.githubusercontent.com/wragge/trove-contributor-totals/main/data/trove-contributors-formats.csv"
    )

# %% [markdown]
# By grouping the totals data, we can find who has contributed the most records by zone.

# %%
# Group by zone
df_totals.groupby("zone").apply(
    # This operates on each group's dataframe, reordering, sorting, and displaying the top 5
    lambda x: x[["nuc", "name", "total"]]
    .sort_values(by="total", ascending=False)
    .reset_index(drop=True)
    .head(5)
    # Display the totals as a bar chart
).style.format({"total": "{:,.0f}"}).bar(subset="total")
# Out:
# <style type="text/css">
# #T_0fc9e_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 51.7%, transparent 51.7%);
# }
# #T_0fc9e_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 24.4%, transparent 24.4%);
# }
# #T_0fc9e_row2_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 12.1%, transparent 12.1%);
# }
# #T_0fc9e_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 10.9%, transparent 10.9%);
# }
# #T_0fc9e_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 7.8%, transparent 7.8%);
# }
# #T_0fc9e_row5_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_0fc9e_row6_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 44.6%, transparent 44.6%);
# }
# #T_0fc9e_row7_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 43.5%, transparent 43.5%);
# }
# #T_0fc9e_row8_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 43.1%, transparent 43.1%);
# }
# #T_0fc9e_row9_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 41.8%, transparent 41.8%);
# }
# #T_0fc9e_row10_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 87.2%, transparent 87.2%);
# }
# #T_0fc9e_row11_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 14.8%, transparent 14.8%);
# }
# #T_0fc9e_row12_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 7.0%, transparent 7.0%);
# }
# #T_0fc9e_row13_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 5.2%, transparent 5.2%);
# }
# #T_0fc9e_row14_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 4.1%, transparent 4.1%);
# }
# #T_0fc9e_row15_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 3.4%, transparent 3.4%);
# }
# #T_0fc9e_row16_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 1.5%, transparent 1.5%);
# }
# #T_0fc9e_row17_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 1.2%, transparent 1.2%);
# }
# #T_0fc9e_row18_col2, #T_0fc9e_row19_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.3%, transparent 0.3%);
# }
# #T_0fc9e_row20_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 12.6%, transparent 12.6%);
# }
# #T_0fc9e_row21_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 5.8%, transparent 5.8%);
# }
# #T_0fc9e_row22_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 5.6%, transparent 5.6%);
# }
# #T_0fc9e_row23_col2, #T_0fc9e_row25_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 5.0%, transparent 5.0%);
# }
# #T_0fc9e_row24_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 3.8%, transparent 3.8%);
# }
# #T_0fc9e_row26_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 1.6%, transparent 1.6%);
# }
# #T_0fc9e_row27_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 1.4%, transparent 1.4%);
# }
# #T_0fc9e_row28_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.7%, transparent 0.7%);
# }
# #T_0fc9e_row29_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.5%, transparent 0.5%);
# }
# #T_0fc9e_row30_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 16.5%, transparent 16.5%);
# }
# #T_0fc9e_row31_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 14.7%, transparent 14.7%);
# }
# #T_0fc9e_row32_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 14.4%, transparent 14.4%);
# }
# #T_0fc9e_row33_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 8.3%, transparent 8.3%);
# }
# #T_0fc9e_row34_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 7.1%, transparent 7.1%);
# }
# </style>
# <table id="T_0fc9e">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0fc9e_level0_col0" class="col_heading level0 col0" >nuc</th>
#       <th id="T_0fc9e_level0_col1" class="col_heading level0 col1" >name</th>
#       <th id="T_0fc9e_level0_col2" class="col_heading level0 col2" >total</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >zone</th>
#       <th class="index_name level1" >&nbsp;</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0fc9e_level0_row0" class="row_heading level0 row0" rowspan="5">article</th>
#       <th id="T_0fc9e_level1_row0" class="row_heading level1 row0" >0</th>
#       <td id="T_0fc9e_row0_col0" class="data row0 col0" >ANL:DL</td>
#       <td id="T_0fc9e_row0_col1" class="data row0 col1" >Trove Digital Library.</td>
#       <td id="T_0fc9e_row0_col2" class="data row0 col2" >1,804,128</td>
#     </tr>
#     <tr>
#       <th id="T_0fc9e_level1_row1" class="row_heading level1 row1" >1</th>
#       <td id="T_0fc9e_row1_col0" class="data row1 col0" >ANL</td>
#       <td id="T_0fc9e_row1_col1" class="data row1 col1" >National Library of Australia.</td>
#       <td id="T_0fc9e_row1_col2" class="data row1 col2" >852,604</td>
#     </tr>
#     <tr>
#       <th id="T_0fc9e_level1_row2" class="row_heading level1 row2" >2</th>
#       <td id="T_0fc9e_row2_col0" class="data row2 col0" >QU:IR</td>
#       <td id="T_0fc9e_row2_col1" class="data row2 col1" >The University of Queensland. University of Queensland Library. University of Queensland: Institutional Repository.</td>
#       <td id="T_0fc9e_row2_col2" class="data row2 col2" >421,583</td>
#     </tr>
#     <tr>
#       <th id="T_0fc9e_level1_row3" class="row_heading level1 row3" >3</th>
#       <td id="T_0fc9e_row3_col0" class="data row3 col0" >APAR:PR</td>
#       <td id="T_0fc9e_row3_col1" class="data row3 col1" >Parliament of  Australia. Parliamentary Library. Press Releases Database.</td>
#       <td id="T_0fc9e_row3_col2" class="data row3 col2" >380,935</td>
#     </tr>
#     <tr>
#       <th id="T_0fc9e_level1_row4" class="row_heading level1 row4" >4</th>
#       <td id="T_0fc9e_row4_col0" class="data row4 col0" >VSL</td>
#       <td id="T_0fc9e_row4_col1" class="data row4 col1" >State Library Victoria.</td>
#       <td id="T_0fc9e_row4_col2" class="data row4 col2" >273,336</td>
#     </tr>
#     <tr>
#       <th id="T_0fc9e_level0_row5" class="row_heading level0 row5" rowspan="5">book</th>
#       <th id="T_0fc9e_level1_row5" class="row_heading level1 row5" >0</th>
#       <td id="T_0fc9e_row5_col0" class="data row5 col0" >ANL</td>
#       <td id="T_0fc9e_row5_col1" class="data row5 col1" >National Library of Australia.</td>
#       <td id="T_0fc9e_row5_col2" class="data row5 col2" >3,488,973</td>
#     </tr>
#     <tr>
#       <th id="T_0fc9e_level1_row6" class="row_heading level1 row6" >1</th>
#       <td id="T_0fc9e_row6_col0" class="data row6 col0" >QU</td>
#       <td id="T_0fc9e_row6_col1" class="data row6 col1" >The University of Queensland. University of Queensland Library.</td>
#       <td id="T_0fc9e_row6_col2" class="data row6 col2" >1,557,222</td>
#     </tr>
#     <tr>
#       <th id="T_0fc9e_level1_row7" class="row_heading level1 row7" >2</th>
#       <td id="T_0fc9e_row7_col0" class="data row7 col0" >VLU</td>
#       <td id="T_0fc9e_row7_col1" class="data row7 col1" >La Trobe University. La Trobe University Library.</td>
#       <td id="T_0fc9e_row7_col2" class="data row7 col2" >1,518,937</td>
#     </tr>
#     <tr>
#       <th id="T_0fc9e_level1_row8" class="row_heading level1 row8" >3</th>
#       <td id="T_0fc9e_row8_col0" class="data row8 col0" >VSL</td>
#       <td id="T_0fc9e_row8_col1" class="data row8 col1" >State Library Victoria.</td>
#       <td id="T_0fc9e_row8_col2" class="data row8 col2" >1,503,395</td>
#     </tr>
#     <tr>
#       <th id="T_0fc9e_level1_row9" class="row_heading level1 row9" >4</th>
#       <td id="T_0fc9e_row9_col0" class="data row9 col0" >VU</td>
#       <td id="T_0fc9e_row9_col1" class="data row9 col1" >The University of Melbourne. The University of Melbourne Library.</td>
#       <td id="T_0fc9e_row9_col2" class="data row9 col2" >1,459,231</td>
#     </tr>
#     <tr>
#       <th id="T_0fc9e_level0_row10" class="row_

# %% [markdown]
# ## Explore an individual zone

# %% [markdown]
# To make it easier to look at the make-up of each zone, we can add a `%` column to the dataframe that shows the proportion each source has contributed.

# %%
# This nifty one-liner to get percentages by group was found here: https://stackoverflow.com/a/57359372
df_totals["%"] = (
    100 * df_totals["total"] / df_totals.groupby("zone")["total"].transform("sum")
)

# %% [markdown]
# Let's have a look at the `collection` zone that includes archives, manuscripts, and other unpublished materials.
#
# How many different contributors provide records to the `collection` zone?

# %%
df_totals.loc[(df_totals["zone"] == "collection") & (df_totals["total"] > 0)][
    "nuc"
].nunique()
# Out:
# 784

# %% [markdown]
# Let's list the top twenty contributors to the `collection` zone.

# %%
df_totals.loc[df_totals["zone"] == "collection"].sort_values(
    by="total", ascending=False
).head(20).style.format({"total": "{:,.0f}"}).bar(subset="%").hide(axis="index")
# Out:
# <style type="text/css">
# #T_7138e_row0_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_7138e_row1_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 17.0%, transparent 17.0%);
# }
# #T_7138e_row2_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 8.0%, transparent 8.0%);
# }
# #T_7138e_row3_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 6.0%, transparent 6.0%);
# }
# #T_7138e_row4_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 4.7%, transparent 4.7%);
# }
# #T_7138e_row5_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 3.7%, transparent 3.7%);
# }
# #T_7138e_row6_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 3.1%, transparent 3.1%);
# }
# #T_7138e_row7_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 2.1%, transparent 2.1%);
# }
# #T_7138e_row8_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 1.1%, transparent 1.1%);
# }
# #T_7138e_row9_col4, #T_7138e_row10_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 1.0%, transparent 1.0%);
# }
# #T_7138e_row11_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.7%, transparent 0.7%);
# }
# #T_7138e_row12_col4, #T_7138e_row13_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.6%, transparent 0.6%);
# }
# #T_7138e_row14_col4, #T_7138e_row15_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.5%, transparent 0.5%);
# }
# #T_7138e_row16_col4, #T_7138e_row17_col4, #T_7138e_row18_col4, #T_7138e_row19_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.4%, transparent 0.4%);
# }
# </style>
# <table id="T_7138e">
#   <thead>
#     <tr>
#       <th id="T_7138e_level0_col0" class="col_heading level0 col0" >nuc</th>
#       <th id="T_7138e_level0_col1" class="col_heading level0 col1" >name</th>
#       <th id="T_7138e_level0_col2" class="col_heading level0 col2" >zone</th>
#       <th id="T_7138e_level0_col3" class="col_heading level0 col3" >total</th>
#       <th id="T_7138e_level0_col4" class="col_heading level0 col4" >%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_7138e_row0_col0" class="data row0 col0" >QSA</td>
#       <td id="T_7138e_row0_col1" class="data row0 col1" >Queensland State Archives.</td>
#       <td id="T_7138e_row0_col2" class="data row0 col2" >collection</td>
#       <td id="T_7138e_row0_col3" class="data row0 col3" >3,043,694</td>
#       <td id="T_7138e_row0_col4" class="data row0 col4" >62.655373</td>
#     </tr>
#     <tr>
#       <td id="T_7138e_row1_col0" class="data row1 col0" >NSCA</td>
#       <td id="T_7138e_row1_col1" class="data row1 col1" >City of Sydney Archives.</td>
#       <td id="T_7138e_row1_col2" class="data row1 col2" >collection</td>
#       <td id="T_7138e_row1_col3" class="data row1 col3" >517,023</td>
#       <td id="T_7138e_row1_col4" class="data row1 col4" >10.643077</td>
#     </tr>
#     <tr>
#       <td id="T_7138e_row2_col0" class="data row2 col0" >NPAR:PR</td>
#       <td id="T_7138e_row2_col1" class="data row2 col1" >Parliament of New South Wales. NSW Parliamentary Library Press Releases.</td>
#       <td id="T_7138e_row2_col2" class="data row2 col2" >collection</td>
#       <td id="T_7138e_row2_col3" class="data row2 col3" >244,083</td>
#       <td id="T_7138e_row2_col4" class="data row2 col4" >5.024523</td>
#     </tr>
#     <tr>
#       <td id="T_7138e_row3_col0" class="data row3 col0" >VUMA</td>
#       <td id="T_7138e_row3_col1" class="data row3 col1" >The University of Melbourne. University of Melbourne Archives.</td>
#       <td id="T_7138e_row3_col2" class="data row3 col2" >collection</td>
#       <td id="T_7138e_row3_col3" class="data row3 col3" >182,226</td>
#       <td id="T_7138e_row3_col4" class="data row3 col4" >3.751178</td>
#     </tr>
#     <tr>
#       <td id="T_7138e_row4_col0" class="data row4 col0" >NSL</td>
#       <td id="T_7138e_row4_col1" class="data row4 col1" >State Library of NSW.</td>
#       <td id="T_7138e_row4_col2" class="data row4 col2" >collection</td>
#       <td id="T_7138e_row4_col3" class="data row4 col3" >144,348</td>
#       <td id="T_7138e_row4_col4" class="data row4 col4" >2.971448</td>
#     </tr>
#     <tr>
#       <td id="T_7138e_row5_col0" class="data row5 col0" >ANL:AJCP</td>
#       <td id="T_7138e_row5_col1" class="data row5 col1" >Australian Joint Copying Project.</td>
#       <td id="T_7138e_row5_col2" class="data row5 col2" >collection</td>
#       <td id="T_7138e_row5_col3" class="data row5 col3" >113,185</td>
#       <td id="T_7138e_row5_col4" class="data row5 col4" >2.329948</td>
#     </tr>
#     <tr>
#       <td id="T_7138e_row6_col0" class="data row6 col0" >ANL</td>
#       <td id="T_7138e_row6_col1" class="data row6 col1" >National Library of Australia.</td>
#       <td id="T_7138e_row6_col2" class="data row6 col2" >collection</td>
#       <td id="T_7138e_row6_col3" class="data row6 col3" >93,073</td>
#       <td id="T_7138e_row6_col4" class="data row6 col4" >1.915936</td>
#     </tr>
#     <tr>
#       <td id="T_7138e_row7_col0" class="data row7 col0" >VSL</td>
#       <td id="T_7138e_row7_col1" class="data row7 col1" >State Library Victoria.</td>
#       <td id="T_7138e_row7_col2" class="data row7 col2" >collection</td>
#       <td id="T_7138e_row7_col3" class="data row7 col3" >63,248</td>
#       <td id="T_7138e_row7_col4" class="data row7 col4" >1.301979</td>
#     </tr>
#     <tr>
#       <td id="T_7138e_row8_col0" class="data row8 col0" >ANL:DL</td>
#       <td id="T_7138e_row8_col1" class="data row8 col1" >Trove Digital Library.</td>
#       <td id="T_7138e_row8_col2" class="data row8 col2" >collection</td>
#       <td id="T_7138e_row8_col3" class="data row8 col3" >32,218</td>
#       <td id="T_7138e_row8_col4" class="data row8 col4" >0.663217</td>
#     </tr>
#     <tr>
#       <td id="T_7138e_row9_col0" class="data row9 col0" >VRHS</td>
#       <td id="T_7138e_row9_col1" class="data row9 col1" >Royal Historical Society of Victoria. Royal Historical Society of Victoria.</td>
#       <td id="T_7138e_row9_col2" class="data row9 col2" >collection</td>
#       <td id="T_7138e_row9_col3" class="data row9 col3" >30,588</td>
#       <td id="T_7138e_row9_col4" class="data row9 col4" >0.629663</td>
#     </tr>
#     <tr>
#       <td id="T_7138e_row10_col0" class="data row10 col0" >SFU</td>
#       <td id="T_7138e_row10_col1" class="data row10 col1" >Flinders University. Flinders University Central Library.</td>
#       <td id="T_7138e_row10_col2" class="data row10 col2" >collection</td>
#       <td id="T_7138e_row10_col3" class="data row10 col3" >30,051</td>
#       <td id="T_7138e_row10_col4" class="data row10 col4" >0.618609</td>
#     </tr>
#     <tr>
#       <td id="T_7138e_row11_col0" class="data row11 col0" >AAS:FA</td>
#       <td id="T_7138e_row11_col1" class="data row11 col1" >Australian Academy of Science. Fenner Archives.</td>
#       <td id="T_7138e_row11_col2" class="data row11 col2" >collection</td>
#       <td id="T_7138e_row11_col3" class="data row11 col3" >20,037</td>
#       <td id="T_7138e_row11_col4" class="data row11 col4" >0.412468</td>
#     </tr>
#     <tr>
#       <td id="T_7138e_row12_col0" class="data row12 col0" >VNG</td>
#       <td id="T_7138e_row12_col1" class="data row12 col1" >National Gallery of Victoria. The Shaw Research Library.</td>
#       <td id="T_7138e_row12_col2" class="data row12 col2" >collection</td>
#       <td id="T_7138e_row12_col3" class="data row12 col3" >17,751</td>
#       <td id="T_7138e_row12_col4" class="data row12 col4" >0.365410</td>
#     </tr>
#     <tr>
#       <td id="T_7138e_row13_col0" class="data row13 col0" >NMMU:C</td>
#       <td id="T_7138e_row13_col1" class="data row13 col1" >Australian National Maritime Museum. Collection.</td>
#       <td id="T_7138e_row13_col2" class="data row13 col2" >collection</td>
#       <td id="T_7138e_row13_col3" class="data row13 col3" >17,230</td>
#       <td id="T_7138e_row13_col4" class="data row13 col4" >0.354685</td>
#     </tr>
#     <tr>
#       <td id="T_7138e_row14_col0" class="data row14 col0" >VPRO</td>
#       <td id="T_7138e_row14_col1" class="data row14 col1" >Pub

# %% [markdown]
# ## Theses from institutional repositories
#
# We can use the formats dataset to drill down further. The NUC symbols of institutional repositories generally end in ':IR', so we look to see how many theses are being contributed by institutional repositories in Australian universities.

# %%
df_formats = df_formats[["name", "nuc", "zone", "format", "total"]]
df_formats.loc[
    # Filter by format 'Thesis'
    (df_formats["format"] == "Thesis")
    # Only universities
    & (df_formats["name"].str.contains("University"))
    # Only institutional repositories
    & (df_formats["nuc"].str.endswith(":IR"))
].sort_values(by="total", ascending=False).style.format({"total": "{:,.0f}"}).bar(
    subset="total"
).hide(
    axis="index"
)
# Out:
# <style type="text/css">
# #T_04867_row0_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_04867_row1_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 87.8%, transparent 87.8%);
# }
# #T_04867_row2_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 72.8%, transparent 72.8%);
# }
# #T_04867_row3_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 58.6%, transparent 58.6%);
# }
# #T_04867_row4_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 50.5%, transparent 50.5%);
# }
# #T_04867_row5_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 48.5%, transparent 48.5%);
# }
# #T_04867_row6_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 31.1%, transparent 31.1%);
# }
# #T_04867_row7_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 19.6%, transparent 19.6%);
# }
# #T_04867_row8_col4, #T_04867_row9_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 18.5%, transparent 18.5%);
# }
# #T_04867_row10_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 18.2%, transparent 18.2%);
# }
# #T_04867_row11_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 17.9%, transparent 17.9%);
# }
# #T_04867_row12_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 17.4%, transparent 17.4%);
# }
# #T_04867_row13_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 16.9%, transparent 16.9%);
# }
# #T_04867_row14_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 16.7%, transparent 16.7%);
# }
# #T_04867_row15_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 16.1%, transparent 16.1%);
# }
# #T_04867_row16_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 13.2%, transparent 13.2%);
# }
# #T_04867_row17_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 12.2%, transparent 12.2%);
# }
# #T_04867_row18_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 11.9%, transparent 11.9%);
# }
# #T_04867_row19_col4, #T_04867_row20_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 10.2%, transparent 10.2%);
# }
# #T_04867_row21_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 9.7%, transparent 9.7%);
# }
# #T_04867_row22_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 9.0%, transparent 9.0%);
# }
# #T_04867_row23_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 7.6%, transparent 7.6%);
# }
# #T_04867_row24_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 7.4%, transparent 7.4%);
# }
# #T_04867_row25_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 4.9%, transparent 4.9%);
# }
# #T_04867_row26_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 3.7%, transparent 3.7%);
# }
# #T_04867_row27_col4, #T_04867_row28_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 2.8%, transparent 2.8%);
# }
# #T_04867_row29_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.2%, transparent 0.2%);
# }
# #T_04867_row30_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.1%, transparent 0.1%);
# }
# #T_04867_row31_col4, #T_04867_row32_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.0%, transparent 0.0%);
# }
# </style>
# <table id="T_04867">
#   <thead>
#     <tr>
#       <th id="T_04867_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_04867_level0_col1" class="col_heading level0 col1" >nuc</th>
#       <th id="T_04867_level0_col2" class="col_heading level0 col2" >zone</th>
#       <th id="T_04867_level0_col3" class="col_heading level0 col3" >format</th>
#       <th id="T_04867_level0_col4" class="col_heading level0 col4" >total</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_04867_row0_col0" class="data row0 col0" >The University of Queensland. University of Queensland Library. University of Queensland: Institutional Repository.</td>
#       <td id="T_04867_row0_col1" class="data row0 col1" >QU:IR</td>
#       <td id="T_04867_row0_col2" class="data row0 col2" >book</td>
#       <td id="T_04867_row0_col3" class="data row0 col3" >Thesis</td>
#       <td id="T_04867_row0_col4" class="data row0 col4" >26,037</td>
#     </tr>
#     <tr>
#       <td id="T_04867_row1_col0" class="data row1 col0" >UNSW Sydney. UNSW Library. University of New South Wales: Institutional Repository.</td>
#       <td id="T_04867_row1_col1" class="data row1 col1" >NUN:IR</td>
#       <td id="T_04867_row1_col2" class="data row1 col2" >book</td>
#       <td id="T_04867_row1_col3" class="data row1 col3" >Thesis</td>
#       <td id="T_04867_row1_col4" class="data row1 col4" >22,851</td>
#     </tr>
#     <tr>
#       <td id="T_04867_row2_col0" class="data row2 col0" >The University of Melbourne. The University of Melbourne Library. University of Melbourne: Institutional Repository.</td>
#       <td id="T_04867_row2_col1" class="data row2 col1" >VU:IR</td>
#       <td id="T_04867_row2_col2" class="data row2 col2" >book</td>
#       <td id="T_04867_row2_col3" class="data row2 col3" >Thesis</td>
#       <td id="T_04867_row2_col4" class="data row2 col4" >18,955</td>
#     </tr>
#     <tr>
#       <td id="T_04867_row3_col0" class="data row3 col0" >Australian National University. Australian National University Library. Australian National University: Institutional Repository.</td>
#       <td id="T_04867_row3_col1" class="data row3 col1" >ANU:IR</td>
#       <td id="T_04867_row3_col2" class="data row3 col2" >book</td>
#       <td id="T_04867_row3_col3" class="data row3 col3" >Thesis</td>
#       <td id="T_04867_row3_col4" class="data row3 col4" >15,254</td>
#     </tr>
#     <tr>
#       <td id="T_04867_row4_col0" class="data row4 col0" >The University of Sydney. University of Sydney Library. University of Sydney: Institutional Repository.</td>
#       <td id="T_04867_row4_col1" class="data row4 col1" >NU:IR</td>
#       <td id="T_04867_row4_col2" class="data row4 col2" >book</td>
#       <td id="T_04867_row4_col3" class="data row4 col3" >Thesis</td>
#       <td id="T_04867_row4_col4" class="data row4 col4" >13,159</td>
#     </tr>
#     <tr>
#       <td id="T_04867_row5_col0" class="data row5 col0" >University of Adelaide. University of Adelaide: Institutional Repository.</td>
#       <td id="T_04867_row5_col1" class="data row5 col1" >SUA:IR</td>
#       <td id="T_04867_row5_col2" class="data row5 col2" >book</td>
#       <td id="T_04867_row5_col3" class="data row5 col3" >Thesis</td>
#       <td id="T_04867_row5_col4" class="data row5 col4" >12,625</td>
#     </tr>
#     <tr>
#       <td id="T_04867_row6_col0" class="data row6 col0" >Queensland University of Technology. Queensland University of Technology: Institutional Repository.</td>
#       <td id="T_04867_row6_col1" class="data row6 col1" >QUT:IR</td>
#       <td id="T_04867_row6_col2" class="data row6 col2" >book</td>
#       <td id="T_04867_row6_col3" class="data row6 col3" >Thesis</td>
#       <td id="T_04867_row6_col4" class="data row6 col4" >8,097</td>
#     </tr>
#     <tr>
#       <td id="T_04867_row7_col0" class="data row7 col0" >University of South Australia. University of South Australia Library. University of South Australia: Institutional Repository.</td>
#       <td id="T_04867_row7_col1" class="data row7 col1" >SUSA:IR</td>
#       <td id="T_04867_row7_col2" class="data row7 col2" >book</td>
#       <td id="T_04867_row7_col3" class="data row7 col3" >Thesis</td>
#       <td id="T_04867_row7_col4" class="data row7 col4" >5,091</td>
#     </tr>
#     <tr>
#       <td id="T_04867_row8_col0" class="data row8 col0" >Macquarie University. Macquarie University Library. Macquarie University Library: Institutional Repository.</td>
#       <td id="T_04867_row8_col1" class="data row8 col1" >NMQU:IR</td>
#       <td id="T_04867_row8_col2" class="data row8 col2" >book</td>
#       <td id="T_04867_row8_col3" class="data row8 col3" >Thesis</td>
#       <td id="T_04867_row8_col4" class="data row8 col4" >4,827</td>
#     </tr>
#     <tr>
#       <td id="T_04867_row9_col0" class="data row9 col0" >RMIT Univers

# %% [markdown]
# ----
#
# Created by [Tim Sherratt](https://timsherratt.org/) for the [GLAM Workbench](https://glam-workbench.net/). Support this project by becoming a [GitHub sponsor](https://github.com/sponsors/wragge).
